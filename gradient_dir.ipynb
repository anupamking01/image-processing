# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# %matplotlib inline
im = np.array(cv2.imread('images/daisy.jpg',cv2.IMREAD_GRAYSCALE), dtype='float')
# im = ((im/255)**0.4)*255
plt.imshow(im, cmap='gray')

# %%
stime = time.time()
kernelx = np.array([[-1,0,1], [-2,0,2], [-1,0,1]])
kernely = np.array([[1,2,1], [0,0,0], [-1,-2,-1]])
gx = cv2.filter2D(out, -1, kernelx)
gy = cv2.filter2D(out, -1, kernely)

# plt.imshow(gy, cmap='gray')
# plt.colorbar()
mag = (gx**2 + gy**2)**(1/2)
ang = np.arctan(gy/(gx+0.0001))
ang = ang*(180/np.pi)
ang = np.where(ang<0,ang+180, ang)
# gx.dtype, ang.dtype
# ang = np.where(ang<0,ang+180,ang)
print(f'{time.time()-stime} secs')
# Out:
# 0.0 secs

# %%
# %matplotlib qt
plt.subplot(121)
plt.imshow(mag,cmap='gray')
plt.colorbar()
plt.subplot(122)
plt.imshow(ang,cmap='twilight') # hsv, twilight_shifted, twilight
plt.colorbar()

# %%
np.min(ang), np.max(ang)
# Out:
# (0.0, 180.0)

# %%
v=100*np.pi
# plt.subplot(121)
plt.plot(np.linspace(-v,v,1000), np.sin(np.linspace(-v,v,1000)))
plt.plot(np.linspace(-v,v,1000), np.cos(np.linspace(-v,v,1000)))
plt.plot(np.linspace(-v,v,1000), np.tan(np.linspace(-v,v,1000)))
# plt.subplot(122)
# plt.plot(np.arctan(np.linspace(s,e)),np.arctan(np.linspace(s,e))*(180/np.pi))

# %%
# %matplotlib qt
kernel = np.array([[0,0,0],[1,0,-1],[0,0,0]])
sharp = cv2.filter2D(blur, -1, kernel)
plt.subplot(121)
plt.imshow(sharp,cmap='gray')
plt.colorbar()

kernel2 = np.array([[1,-1],[0,0]])
sharp2 = cv2.filter2D(blur, -1, kernel)
plt.subplot(122)
plt.imshow(sharp2,cmap='gray')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-8ad784624b5e> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 kernel = np.array([[0,0,0],[1,0,-1],[0,0,0]])
# ----> 3 sharp = cv2.filter2D(blur, -1, kernel)
#       4 plt.subplot(121)
#       5 plt.imshow(sharp,cmap='gray')
#
# NameError: name 'blur' is not defined

# %%
np.linalg.norm([1,2,3,4], ord='1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\venv_der\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2483             try:
# -> 2484                 ord + 1
#    2485             except TypeError:
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-3c28724eb3dd> in <module>
# ----> 1 np.linalg.norm([1,2,3,4], ord='1')
#
# ~\Anaconda3\envs\venv_der\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2484                 ord + 1
#    2485             except TypeError:
# -> 2486                 raise ValueError("Invalid norm order for vectors.")
#    2487             absx = abs(x)
#    2488             absx **= ord
#
# ...
