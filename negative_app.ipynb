# %%
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
path = "images/x_ray.jpg"
img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
img = 255 - img
plt.imshow(img,cmap="gray")
img.shape
# Out:
# (570, 800)

# %%
# for i in range(img.shape[0]):
#     img[i] = 255 - img[i]
img = 255 - img
plt.imshow(img,cmap="gray")
